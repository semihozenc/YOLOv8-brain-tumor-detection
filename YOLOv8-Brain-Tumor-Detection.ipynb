# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.3/664.3 kB 8.2 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/Source
# Out:
# /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/Source

# %%
# !ls
# Out:
#  data.yaml						  README.dataset.txt    test    valid
# 'MRI BRAIN TUMOR.v1-braintumorsample1.0.yolov8 (1).zip'   README.roboflow.txt   train   yolov8n.pt

# %%
# unzipping dataset
# !unzip "MRI BRAIN TUMOR.v1-braintumorsample1.0.yolov8 (1).zip"
# Out:
# Archive:  MRI BRAIN TUMOR.v1-braintumorsample1.0.yolov8 (1).zip
#  extracting: README.dataset.txt
#  extracting: README.roboflow.txt
#  extracting: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/Y11_jpg.rf.a2927aa6c18c3e171759794c652f7a94.jpg
#  extracting: test/images/Y15_jpg.rf.ef14d75b886fd9ce299d12ffe480c5e9.jpg
#  extracting: test/images/Y16_JPG.rf.96e3fc38718c5f64776810040e63363c.jpg
#  extracting: test/images/Y25_jpg.rf.44dd79b8fc37ba37125a4aaded54ac7c.jpg
#  extracting: test/images/Y29_jpg.rf.307e980d22d7cea7aed340d4f0edc9bc.jpg
#  extracting: test/images/Y33_jpg.rf.f3e7bf77085ecd9dd6c9cfbc268b8fc0.jpg
#  extracting: test/images/Y35_jpg.rf.2708ac47796b51b380ca8f3cf8fcc821.jpg
#  extracting: test/images/Y49_JPG.rf.f5d86858ea33cd0f3b814c9705d731e5.jpg
#  extracting: test/images/Y53_jpg.rf.127aa793704719025b736da0a3da5f1d.jpg
#  extracting: test/images/Y61_jpg.rf.dc5523efe774025db6024db44e703c07.jpg
# ...

# %%
#Training YOLOv8 on a custom dataset
# !yolo task = detect mode = train model = yolov8n.pt data = /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/Source/data.yaml epochs = 100 imgsz= 416 project = /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/New_Results
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Predicting using our custom trained YOLOv8 model
# !yolo task = detect mode = predict model = /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/New_Results/train/weights/best.pt source = /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/Source/test/images/Y90_jpg.rf.85255f00a6965b30d7b6caab53b655f3.jpg  project = /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/New_Results
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/Source/test/images/Y90_jpg.rf.85255f00a6965b30d7b6caab53b655f3.jpg: 672x672 1 YES-TUMOR, 16.8ms
# Speed: 7.4ms preprocess, 16.8ms inference, 940.0ms postprocess per image at shape (1, 3, 672, 672)
# Results saved to /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/New_Results/predict7
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task = detect mode = predict model = /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/New_Results/train/weights/best.pt source = /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/Source/test/images/Y25_jpg.rf.44dd79b8fc37ba37125a4aaded54ac7c.jpg  project = /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/New_Results
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/Source/test/images/Y25_jpg.rf.44dd79b8fc37ba37125a4aaded54ac7c.jpg: 672x672 1 YES-TUMOR, 8.8ms
# Speed: 5.4ms preprocess, 8.8ms inference, 513.0ms postprocess per image at shape (1, 3, 672, 672)
# Results saved to /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/New_Results/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task = detect mode = predict model = /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/New_Results/train/weights/best.pt source = /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/Source/test/images/Y35_jpg.rf.2708ac47796b51b380ca8f3cf8fcc821.jpg  project = /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/New_Results
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/Source/test/images/Y35_jpg.rf.2708ac47796b51b380ca8f3cf8fcc821.jpg: 672x672 1 YES-TUMOR, 9.6ms
# Speed: 5.4ms preprocess, 9.6ms inference, 669.1ms postprocess per image at shape (1, 3, 672, 672)
# Results saved to /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/New_Results/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task = detect mode = predict model = /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/New_Results/train/weights/best.pt source = /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/Source/test/images/deneme.jpg  project = /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/New_Results
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/Source/test/images/deneme.jpg: 384x672 (no detections), 107.8ms
# Speed: 3.5ms preprocess, 107.8ms inference, 21.1ms postprocess per image at shape (1, 3, 384, 672)
# Results saved to /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/New_Results/predict6
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task = detect mode = predict model = /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/New_Results/train/weights/best.pt source = /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/Source/test/images  project = /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/New_Results
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/12 /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/Source/test/images/Y11_jpg.rf.a2927aa6c18c3e171759794c652f7a94.jpg: 672x672 1 YES-TUMOR, 8.8ms
# image 2/12 /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/Source/test/images/Y15_jpg.rf.ef14d75b886fd9ce299d12ffe480c5e9.jpg: 672x672 (no detections), 7.9ms
# image 3/12 /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/Source/test/images/Y16_JPG.rf.96e3fc38718c5f64776810040e63363c.jpg: 672x672 (no detections), 7.7ms
# image 4/12 /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/Source/test/images/Y25_jpg.rf.44dd79b8fc37ba37125a4aaded54ac7c.jpg: 672x672 1 YES-TUMOR, 7.7ms
# ...

# %%
import matplotlib.pyplot as plt
import cv2

original_image = cv2.imread('/content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/Source/test/images/Y25_jpg.rf.44dd79b8fc37ba37125a4aaded54ac7c.jpg')
plt.imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))

# %%
# !yolo task = detect mode = predict model = /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/New_Results/train/weights/best.pt source = /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/Source/test/images/Y25_jpg.rf.44dd79b8fc37ba37125a4aaded54ac7c.jpg  project = /content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/New_Results

# %%
predicted_image = cv2.imread('/content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/New_Results/predict2/Y25_jpg.rf.44dd79b8fc37ba37125a4aaded54ac7c.jpg')
plt.imshow(cv2.cvtColor(predicted_image, cv2.COLOR_BGR2RGB))

# %%
original_image = cv2.imread('/content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/Source/test/images/deneme.jpg')
plt.imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))

# %%
predicted_image = cv2.imread('/content/drive/MyDrive/YOLOv8-Brain-Tumor-Detection/New_Results/predict6/deneme.jpg')
plt.imshow(cv2.cvtColor(predicted_image, cv2.COLOR_BGR2RGB))
